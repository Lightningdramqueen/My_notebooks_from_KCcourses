# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
games = pd.read_csv('/home/jupyter-a.kosheleva-14/games.csv', sep = ',')

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.shape
# Out:
# (16598, 11)

# %%
games.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
a = list(range(0, 100))

# %%
np.std(a, ddof = 1).round(3)
# Out:
# 29.011

# %%
games = games.dropna()

# %%
games.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
games.Year.describe()
# Out:
# count    16291.000000
# mean      2006.405561
# std          5.832412
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
games.Year.value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
sns.set(rc={'figure.figsize':(20, 5)})
ax = sns.countplot(x="Year", data=games)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-8fde4f1a4e44> in <module>
#       2 ax = sns.countplot(x="Year", data=games)
#       3 ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# ----> 4 plt.tight_layout()
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
games2007 = games.query('Year > 2007.0')

# %%
round(games2007.shape[0]/games.shape[0]*100,2)
# Out:
# 49.06

# %%
platform_count = games.Platform.value_counts(normalize=True)*100

# %%
platform_count
# Out:
# DS      13.080842
# PS2     13.056289
# PS3      8.004420
# Wii      7.918483
# X360     7.574735
# PSP      7.347615
# PS       7.298508
# PC       5.757780
# XB       4.929102
# GBA      4.824750
# GC       3.326990
# 3DS      3.063041
# PSV      2.516727
# PS4      2.062488
# N64      1.939721
# SNES     1.467068
# XOne     1.307470
# SAT      1.061936
# WiiU     0.877785
# 2600     0.712050
# NES      0.601559
# GB       0.595421
# DC       0.319195
# GEN      0.165736
# NG       0.073660
# WS       0.036830
# SCD      0.036830
# 3DO      0.018415
# TG16     0.012277
# PCFX     0.006138
# GG       0.006138
# Name: Platform, dtype: float64

# %%
games.Publisher.value_counts()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# TOHO                               1
# UIG Entertainment                  1
# Ecole                              1
# 989 Sports                         1
# Piacci                             1
# Name: Publisher, Length: 576, dtype: int64

# %%
gamesNintendo = games.query('Publisher == "Nintendo"')

# %%
gamesNintendo
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gamesNintendo[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].agg(['mean', 'median', 'std'])
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# mean    1.172055  0.601006  0.653721     0.136767      2.563836
# median  0.375000  0.120000  0.280000     0.030000      0.920000
# std     2.989913  1.743953  1.063110     0.464170      5.676925

# %%
ax = sns.boxplot(x="Genre", y="JP_Sales", data=gamesNintendo)
sns.set(rc={'figure.figsize':(20,16)})

# %%
filter_list=['Fighting', 'Simulation', 'Platform', 'Racing', 'Sports']
gamesgenre = gamesNintendo.query("Genre == @filter_list")

# %%
gamesgenre
# Out:
#         Rank                                          Name Platform    Year  \
# 0          1                                    Wii Sports      Wii  2006.0
# 1          2                             Super Mario Bros.      NES  1985.0
# 2          3                                Mario Kart Wii      Wii  2008.0
# 3          4                             Wii Sports Resort      Wii  2009.0
# 6          7                         New Super Mario Bros.       DS  2006.0
# ...      ...                                           ...      ...     ...
# 12123  12125                                  Mario Tennis      Wii  2010.0
# 12770  12772  Dance Dance Revolution: Mario Mix (JP sales)       GC  2005.0
# 14626  14629                                    Calcio Bit      GBA  2006.0
# 14968  14971                                Teddy Together      3DS  2016.0
# 15991  15994                       Donkey Kong Jungle Beat      Wii  2008.0
#
# ...

# %%
gamesgenre1 = gamesgenre.groupby(['Genre','Year'], as_index = False) \
    .sum()

# %%
sns.lineplot(x = 'Year', y = 'Global_Sales', hue = 'Genre', data = gamesgenre1)
sns.set(rc={'figure.figsize':(20,20)})
